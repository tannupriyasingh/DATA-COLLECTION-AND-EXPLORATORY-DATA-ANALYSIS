# %% [markdown]
# # CSE587 DIC Lab 1 Part 1 rakshitm, tannupri

# %%
#Lab 1, Part 1, Problem 1
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34)  # random numbers, Poisson distribution, mean at 34, 12 numbers
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")
lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title “Sales by Month”

# %% [markdown]
# We have setup a sales1 and sales 2 character vectors, one is a 12 integer vector and the other is a Poisson Distributed random integer vector. We then draw a line plot with these 2 vectors which shows the sales by month. We then set the legend to show which line belongs to which vector.

# %%
#Lab 1, Part 2, Problem 2
sales<-read.table('salesdata.txt', header=T)
#sales  # to verify that data has been read
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
# Out:
# Plot with title “Sales Data”

# %% [markdown]
# In the above one, we import data from a text file and load it into a table. Then we plot a bar plot on it, which shows the sales1 and sales2 in the above plot. We converted the data into a matrix so that we can easily plot the data grouped.

# %%
#Lab 1, Part 1, Problem 3
fn<-boxplot(sales,col=c("orange","green"))$stats
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %% [markdown]
# In this one, we want to plot a boxplot using the same sales data from Problem 2. We are finding out what the median in each of the sales data and then plot it accordingly.

# %%
#Lab 1, Part 1, Problem 4
fb1<-read.csv('FB.csv')
aapl1<-read.csv('AAPL.csv')
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(160,200), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)
#Just study the distribution of the adjusted close of the stock price of Apple.
hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# plot without title
# Plot with title “Histogram of aapl1$Adj.Close”

# %% [markdown]
# We read 2 csv files for 2 companies(fb, apple) that contain its stock data. First we plotted a line plot showing the stock price across the day range and saw how the prices changed and how they mix. Then we plotted a histogram for apple's stock only to show its closing price based on frequency.

# %%
#Lab 1, Part 1, Problem 5
library(ggplot2)
attach(mpg)
head(mpg)
summary(mpg)
#after analysis remove the data from the memory
detach(mpg)
#Also explore newer data sets in 
#library (help=datasets)
data(mpg)
head(uspop)
plot(uspop)
# Out:
# Attaching package: ‘ggplot2’
#
# The following object is masked from ‘mtcars’:
#
#     mpg
#
# The following object is masked from ‘mtcars’:
#
#     mpg
#
# The following object is masked from mtcars (pos = 4):
#
#     cyl
#
# The following object is masked from mtcars (pos = 5):
#
#     cyl
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
# ...

# %% [markdown]
# In this problem, we try to find out the commands, data(), attach(). We find the data using head() and summary(). Using the help command in library we see what all is in datasets, then using the plot() command for uspop against time.

# %%
#Lab 1, Part 1, Problem 6
library("ggmap")
library("maptools")
library(maps)
google_api_key <- 'AIzaSyBkxf5ZwATGGsRfjmDh73786lucI--p54o';
register_google(key = google_api_key) 
visited <- c("SFO", "Chennai", "London", "Melbourne", 'Lima,Peru', "Johannesbury, SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Chennai&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Lima,Peru&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,+SA&key=xxx--p54o
# plot without title

# %% [markdown]
# In this problem, we first installed the ggmap and maps library. Then we registered the google key
# and setup a vector with visited citites. Then we found out the geocode for each of these cites using google API and store the lat,lon for each of the cities. Then we use the maps package to plot it around the world using the red dollar sign.

# %%
#Lab 1, Part 1, Problem 6
library("ggmap")
library("maptools")
library(maps)
register_google(key = google_api_key) 
visited <- c("SFO", "New York", "Buffalo", "Dallas, TX")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visit.x,visit.y, col="yellow", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&key=xxx--p54o
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Dallas,+TX&key=xxx--p54o
# plot without title

# %% [markdown]
# In this one similar to the one before, we created a vector with only USA cities, then used the geocode to find the lat, lon for each of the cities. Then we setup the USA map using the maps library in a rainbow color formation and plotted the cities.

# %%
#Lab 1, Part 1, Problem 7
attach(mtcars)
head(mtcars)
plot(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
# Out:
# The following objects are masked from mtcars (pos = 3):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1
# plot without title
# plot without title
# plot without title

# %% [markdown]
# We attached the mtcars dataset and then plotted 3 graphs out of it. In the first one we found out the mpg, disp, hp, drat, wt. In the 2nd plot we removed the drat property and only showed the other ones. The 3rd one is a colored one and with only 4 properties. We used the regular plot() to plot these data.

# %%
#Lab 1, Part 1, Problem 8
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y=disp)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# This is a simple ggplot where we plotted the mtcars disp vs mpg. We plotted a pointer based plot using geom_plot to the show the points, where the x-axis is the mpg and the y-axis is the disp.
